# %%
nums = [1,2,3]
for i in range(len(nums)):
    print(nums[i])

# %%
s = "123"
print(len(s))
# Out:
# 3

# %%
strs = ["eat","tea","tan","ate","nat","bat"]
output = [["bat"],["nat","tan"],["ate","eat","tea"]]

# %%
print("".join(sorted("eat")))
# Out:
# aet

# %%
ee = ["",""]
print(ee)
# Out:
# ['', '']

# %%
from collections import defaultdict
some_dict = defaultdict(list)
some_dict[0].append("val")
some_dict[1].append("other val")
print(some_dict)
# Out:
# defaultdict(<class 'list'>, {0: ['val'], 1: ['other val']})
