# %%
import re
sentence = "A man, a plan, a canal: Panama"

cleaned_string = re.sub(r'[^a-zA-Z]', "", sentence).lower()
print(cleaned_string)
# Out:
# amanaplanacanalpanama

# %%
a,b = 0,0
print(f'{a},{b}')
# Out:
# 0,0

# %%
import re

def isPalindrome(s):
    cleaned_string = re.sub(r'[^a-zA-Z]', "", s).lower()
    print(cleaned_string)
    left = 0
    right = len(cleaned_string)-1
    while left != right:
        if cleaned_string[left] != cleaned_string[right]:
            return False
        left += 1
        right -= 1
    return True

s = "A man, a plan, a canal: Panama"

print(isPalindrome(s))
# Out:
# amanaplanacanalpanama
# True

# %%
s = ""
if not s:
    print("Yes")
# Out:
# Yes
