# %%
nums = [1,2,3,4,5]
print(len(nums))
for i in range(len(nums)):
    print(i)
# Out:
# 5
# 0
# 1
# 2
# 3
# 4

# %%
print(sum(nums[0:1]))
# Out:
# 1

# %%
print(sum(nums[1:3]))
# Out:
# 5

# %%
nums = [1,12,-5,-6,50,3]
left = 0
right = 4
print(nums[left:right])
print(len(nums))
# Out:
# [1, 12, -5, -6]
# 6
